# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Necessary-Liabraries-and-Tools" data-toc-modified-id="Necessary-Liabraries-and-Tools-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Necessary Liabraries and Tools</a></span></li><li><span><a href="#Data-Loader" data-toc-modified-id="Data-Loader-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Loader</a></span><ul class="toc-item"><li><span><a href="#data-description" data-toc-modified-id="data-description-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>data description</a></span></li><li><span><a href="#Data-prep" data-toc-modified-id="Data-prep-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data prep</a></span></li></ul></li><li><span><a href="#Data-analysis-and-visualization" data-toc-modified-id="Data-analysis-and-visualization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data analysis and visualization</a></span><ul class="toc-item"><li><span><a href="#Data-Visualization" data-toc-modified-id="Data-Visualization-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data Visualization</a></span><ul class="toc-item"><li><span><a href="#Gender" data-toc-modified-id="Gender-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Gender</a></span></li></ul></li></ul></li><li><span><a href="#Prediction-Challenge" data-toc-modified-id="Prediction-Challenge-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Prediction Challenge</a></span></li><li><span><a href="#Exploratory-Component" data-toc-modified-id="Exploratory-Component-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploratory Component</a></span></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Conclusions</a></span></li></ul></div>

# %% [markdown]
# # Necessary Liabraries and Tools

# %%
import pandas as pd
import matplotlib.pyplot as plt

from DataLoader import DataLoader

# %% [markdown]
# # Data Loader

# %%
# read the existing subset of the data
df = DataLoader.read_data('Trips_subset.csv')
df.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0           970  2018-01-01 13:50:57.4340
# 1           1           723  2018-01-01 15:33:30.1820
# 2           2           496  2018-01-01 15:39:18.3370
# 3           3           306  2018-01-01 15:40:13.3720
# 4           4           306  2018-01-01 18:14:51.5680
#
#                    stoptime  start_station_id  start_station_latitude  \
# 0  2018-01-01 14:07:08.1860              72.0               40.767272
# 1  2018-01-01 15:45:33.3410              72.0               40.767272
# 2  2018-01-01 15:47:35.1720              72.0               40.767272
# 3  2018-01-01 15:45:20.1910              72.0               40.767272
# 4  2018-01-01 18:19:57.6420              72.0               40.767272
#
#    start_station_longitude  end_station_id  end_station_latitude  \
# 0               -73.993929           505.0             40.749013
# 1               -73.993929          3255.0             40.750585
# ...

# %%
df.T[:10]
# Out:
#                                              0       \
# Unnamed: 0                                        0
# tripduration                                    970
# starttime                2018-01-01 13:50:57.434000
# stoptime                 2018-01-01 14:07:08.186000
# start_station_id                               72.0
# start_station_latitude                    40.767272
# start_station_longitude                  -73.993929
# end_station_id                                505.0
# end_station_latitude                      40.749013
# end_station_longitude                    -73.988484
#
#                                              1       \
# Unnamed: 0                                        1
# tripduration                                    723
# starttime                2018-01-01 15:33:30.182000
# stoptime                 2018-01-01 15:45:33.341000
# start_station_id                               72.0
# start_station_latitude                    40.767272
# ...

# %% [markdown]
# ## data description

# %% [markdown]
# gaining insights into the structure and characteristics of the data

# %%
print(f"the number of the rows = {len(df)} \n")
print(f"dataframe information = {df.info()} \n")
# Out:
# the number of the rows = 140000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               140000 non-null  int64
#  1   tripduration             140000 non-null  int64
#  2   starttime                140000 non-null  object
#  3   stoptime                 140000 non-null  object
#  4   start_station_id         140000 non-null  float64
#  5   start_station_latitude   140000 non-null  float64
#  6   start_station_longitude  140000 non-null  float64
#  7   end_station_id           140000 non-null  float64
#  8   end_station_latitude     140000 non-null  float64
#  9   end_station_longitude    140000 non-null  float64
#  10  bikeid                   140000 non-null  int64
#  11  usertype                 140000 non-null  object
#  12  birth_year               140000 non-null  int64
# ...

# %%
print("data summary statistics = \n")
df.describe()
# Out:
# data summary statistics =
#           Unnamed: 0  tripduration  start_station_id  start_station_latitude  \
# count  140000.000000  1.400000e+05     140000.000000           140000.000000
# mean    69999.500000  7.593562e+02        253.587986               40.723887
# std     40414.663181  1.489349e+04         65.787737                0.018526
# min         0.000000  6.100000e+01         72.000000               40.683826
# 25%     34999.750000  3.090000e+02        223.000000               40.714067
# 50%     69999.500000  4.930000e+02        268.000000               40.724055
# 75%    104999.250000  8.150000e+02        306.000000               40.734546
# max    139999.000000  4.421929e+06        336.000000               40.767272
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            140000.000000   140000.000000         140000.000000
# mean                -73.992639      981.329214             40.726562
# ...

# %% [markdown]
# ## Data prep

# %%
# Convert a datetime column to datetime data type
df['starttime'] = pd.to_datetime(df['starttime'])
df['stoptime'] = pd.to_datetime(df['stoptime'])

# %% [markdown]
# # Data analysis and visualization

# %% [markdown]
# ### Gender

# %%
print(f"available values (classes) for the gender column = {df['gender'].unique()}")
# Out:
# available values (classes) for the gender column = [1 0 2]

# %%
""" Create a bar plot for the "gender" column """

df['gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
""" Create a pie chart for the "gender" column """

gender_counts = df['gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # Prediction Challenge

# %% [markdown]
# # Exploratory Component

# %% [markdown]
# # Conclusions
